# %% [markdown]
# # Load in Libraries

# %%
import pandas as pd
import numpy as np

print('Pandas version', pd.__version__)
print('Numpy version', np.__version__)
# Out:
# Pandas version 0.20.3
# Numpy version 1.14.0

# %% [markdown]
# # Read in Data

# %%
profiles = pd.read_csv('../data/Chicago_Public_Schools_-_School_Profile_Information_SY1617.csv', 
                       encoding = "ISO-8859-1")

# %%
profiles.head()
# Out:
#    School_ID  Legacy_Unit_ID  Finance_ID       Short_Name  \
# 0     610158            5720       29271            SAYRE
# 1     610282            7040       26301           MCNAIR
# 2     609996            4020       23821           HOLDEN
# 3     400079            3344       66395  ACERO - ZIZUMBO
# 4     610089            5020       24621           MURPHY
#
#                                      Long_Name   School_Type Primary_Category  \
# 0  Harriet E Sayre Elementary Language Academy  Neighborhood               ES
# 1            Ronald E McNair Elementary School  Neighborhood               ES
# 2           Charles N Holden Elementary School  Neighborhood               ES
# 3   Acero Charter Schools - SPC Daniel Zizumbo       Charter               ES
# 4              John B Murphy Elementary School  Neighborhood               ES
#
#   Is_High_School Is_Middle_School Is_Elementary_School  \
# 0              N                Y                    Y
# 1              N                Y                    Y
# 2              N                Y                    Y
# 3              N                Y                    Y
# 4              N                Y                    Y
#
#                          ...                         Third_Contact_Name  \
# 0                        ...                                        NaN
# 1                        ...                                Tasia White
# 2                        ...                                        NaN
# 3                        ...                                        NaN
# 4                        ...                              Laura Aguirre
#
#   Fourth_Contact_Title Fourth_Contact_Name Fifth_Contact_Title  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
#
#   Fifth_Contact_Name Sixth_Contact_Title Sixth_Contact_Name  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
#
#   Seventh_Contact_Title Seventh_Contact_Name  \
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN
# 3                   NaN                  NaN
# 4                   NaN                  NaN
#
#                                             Location
# 0  1850 N NEWLAND AVE\rChicago, Illinois 60707\r(...
# 1  4820 W WALTON ST\rChicago, Illinois 60651\r(41...
# 2  1104 W 31ST ST\rChicago, Illinois 60608\r(41.8...
# 3  4248 W 47TH ST\rChicago, Illinois 60632\r(41.8...
# 4  3539 W GRACE ST\rChicago, Illinois 60618\r(41....
#
# [5 rows x 91 columns]

# %%
profiles.columns
# Out:
# Index(['School_ID', 'Legacy_Unit_ID', 'Finance_ID', 'Short_Name', 'Long_Name',
#        'School_Type', 'Primary_Category', 'Is_High_School', 'Is_Middle_School',
#        'Is_Elementary_School', 'Is_Pre_School', 'Summary',
#        'Administrator_Title', 'Administrator', 'Secondary_Contact_Title',
#        'Secondary_Contact', 'Address', 'City', 'State', 'Zip', 'Phone', 'Fax',
#        'CPS_School_Profile', 'Website', 'Facebook', 'Twitter', 'Youtube',
#        'Pinterest', 'Attendance_Boundaries', 'Grades_Offered_All',
#        'Grades_Offered', 'Student_Count_Total', 'Student_Count_Low_Income',
#        'Student_Count_Special_Ed', 'Student_Count_English_Learners',
#        'Student_Count_Black', 'Student_Count_Hispanic', 'Student_Count_White',
#        'Student_Count_Asian', 'Student_Count_Native_American',
#        'Student_Count_Other_Ethnicity', 'Student_Count_Asian_Pacific_Islander',
#        'Student_Count_Multi', 'Student_Count_Hawaiian_Pacific_Islander',
#        'Student_Count_Ethnicity_Not_Available', 'Statistics_Description',
#        'Demographic_Description', 'ADA_Accessible', 'Dress_Code',
#        'PreK_School_Day', 'Kindergarten_School_Day', 'School_Hours',
#        'Freshman_Start_End_Time', 'After_School_Hours',
#        'Earliest_Drop_Off_Time', 'Classroom_Languages', 'Bilingual_Services',
#        'Refugee_Services', 'Title_1_Eligible', 'PreSchool_Inclusive',
#        'Preschool_Instructional', 'Significantly_Modified', 'Hard_Of_Hearing',
#        'Visual_Impairments', 'Transportation_Bus', 'Transportation_El',
#        'Transportation_Metra', 'School_Latitude', 'School_Longitude',
#        'Average_ACT_School', 'Mean_ACT', 'College_Enrollment_Rate_School',
#        'College_Enrollment_Rate_Mean', 'Graduation_Rate_School',
#        'Graduation_Rate_Mean', 'Overall_Rating', 'Rating_Status',
#        'Rating_Statement', 'Classification_Description', 'School_Year',
#        'Third_Contact_Title', 'Third_Contact_Name', 'Fourth_Contact_Title',
#        'Fourth_Contact_Name', 'Fifth_Contact_Title', 'Fifth_Contact_Name',
#        'Sixth_Contact_Title', 'Sixth_Contact_Name', 'Seventh_Contact_Title',
#        'Seventh_Contact_Name', 'Location'],
#       dtype='object')

# %% [markdown]
# # Clean data

# %% [markdown]
# ## Remove unnecessary rows
#
# There are rows in here for elementary and middle schools - we don't need those. Additionally, there are some rows with no graduation rate data and we **aren't interested in the observations if there is no associated target**

# %%
high_schools = profiles.loc[(profiles['Is_High_School']=='Y') & (profiles['Graduation_Rate_School'].notnull())]

# %%
print('Rows:', len(high_schools))
high_schools.head()
# Out:
# Rows: 121
#     School_ID  Legacy_Unit_ID  Finance_ID           Short_Name  \
# 10     609764            1890       46421            JUAREZ HS
# 11     400054            1931       66142  NOBLE - PRITZKER HS
# 12     609726            1500       47051            BROOKS HS
# 14     400094            8058       63081              EPIC HS
# 21     609755            1810       47101             YOUNG HS
#
#                                           Long_Name           School_Type  \
# 10      Benito Juarez Community Academy High School          Neighborhood
# 11                    Noble - Pritzker College Prep               Charter
# 12  Gwendolyn Brooks College Preparatory Academy HS  Selective enrollment
# 14                 EPIC Academy Charter High School               Charter
# 21               Whitney M Young Magnet High School  Selective enrollment
#
#    Primary_Category Is_High_School Is_Middle_School Is_Elementary_School  \
# 10               HS              Y                N                    N
# 11               HS              Y                N                    N
# 12               HS              Y                Y                    N
# 14               HS              Y                N                    N
# 21               HS              Y                Y                    N
#
#                           ...                         Third_Contact_Name  \
# 10                        ...                            Nicholas Aquino
# 11                        ...                                        NaN
# 12                        ...                               Daniel Bauer
# 14                        ...                             Tawanna Patton
# 21                        ...                            Matthew Swanson
#
#    Fourth_Contact_Title Fourth_Contact_Name               Fifth_Contact_Title  \
# 10       IB Coordinator    Santiago Marquez                               NaN
# 11                  NaN                 NaN                               NaN
# 12                  NaN                 NaN                               NaN
# 14  Assistant Principal         Josh Miller  Director of Specialized Services
# 21  Assistant Principal         Melvin Soto               Assistant Principal
#
#    Fifth_Contact_Name                             Sixth_Contact_Title  \
# 10                NaN                                             NaN
# 11                NaN                                             NaN
# 12                NaN                                             NaN
# 14          Dan Grady  Director of External Relations and Recruitment
# 21         Lynn Zalon                                             NaN
#
#    Sixth_Contact_Name Seventh_Contact_Title Seventh_Contact_Name  \
# 10                NaN                   NaN                  NaN
# 11                NaN                   NaN                  NaN
# 12                NaN                   NaN                  NaN
# 14  Demetrius Amparan      Alumni Counselor     Bejeray Morrison
# 21                NaN                   NaN                  NaN
#
#                                              Location
# 10  1450 W CERMAK RD\rChicago, Illinois 60608\r(41...
# 11  4131 W CORTLAND ST\rChicago, Illinois 60639\r(...
# 12  250 E 111TH ST\rChicago, Illinois 60628\r(41.6...
# 14  8255 S HOUSTON AVE\rChicago, Illinois 60617\r(...
# 21  211 S LAFLIN ST\rChicago, Illinois 60607\r(41....
#
# [5 rows x 91 columns]

# %% [markdown]
# ## Remove unnecessary columns
#
# We don't need all these columns, let's reduce our dataset to the fields we need to engineer our features

# %%
schools = high_schools.loc[:, ['School_ID', 
                             'Short_Name',
                             'Long_Name',
                             'School_Type',
                             'Zip',
                             'Facebook',
                             'Twitter',
                             'Student_Count_Total',
                             'Student_Count_Low_Income',
                             'School_Hours',
                             'Transportation_El',
                             'School_Latitude',
                             'School_Longitude',
                             'Average_ACT_School',
                             'Graduation_Rate_School']]

schools.head()
# Out:
#     School_ID           Short_Name  \
# 10     609764            JUAREZ HS
# 11     400054  NOBLE - PRITZKER HS
# 12     609726            BROOKS HS
# 14     400094              EPIC HS
# 21     609755             YOUNG HS
#
#                                           Long_Name           School_Type  \
# 10      Benito Juarez Community Academy High School          Neighborhood
# 11                    Noble - Pritzker College Prep               Charter
# 12  Gwendolyn Brooks College Preparatory Academy HS  Selective enrollment
# 14                 EPIC Academy Charter High School               Charter
# 21               Whitney M Young Magnet High School  Selective enrollment
#
#       Zip                                        Facebook  \
# 10  60608                                             NaN
# 11  60639        https://www.facebook.com/benoblepritzker
# 12  60628                                             NaN
# 14  60617  https://www.facebook.com/EPICAcademyHighSchool
# 21  60607                  http://www.facebook.com/wmymhs
#
#                                Twitter  Student_Count_Total  \
# 10                                 NaN                 1739
# 11  http://twitter.com/benoblepritzker                  992
# 12   https://twitter.com/BrooksPrepCSL                  959
# 14    https://twitter.com/EPIC_Academy                  523
# 21         http://www.twitter.com/wyhs                 2156
#
#     Student_Count_Low_Income                            School_Hours  \
# 10                      1659                     7:45  AM - 2:35  PM
# 11                       936  M - R 8:05AM. - 3:50PM  F 8:05- 1:30PM
# 12                       692                       8:00 AM - 3:30 PM
# 14                       491                         8:10 AM-3:50 PM
# 21                       891                     8:00  AM - 3:15  PM
#
#    Transportation_El  School_Latitude  School_Longitude  Average_ACT_School  \
# 10   Blue, Pink, Red        41.852667        -87.663732                16.5
# 11       Blue, Brown        41.915214        -87.730127                21.9
# 12            Orange        41.692763        -87.616353                22.5
# 14               NaN        41.744849        -87.550222                17.5
# 21              Blue        41.878603        -87.664233                27.9
#
#     Graduation_Rate_School
# 10                    80.9
# 11                    90.3
# 12                    93.4
# 14                    69.9
# 21                    96.2

# %%
schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 121 entries, 10 to 655
# Data columns (total 15 columns):
# School_ID                   121 non-null int64
# Short_Name                  121 non-null object
# Long_Name                   121 non-null object
# School_Type                 121 non-null object
# Zip                         121 non-null int64
# Facebook                    65 non-null object
# Twitter                     70 non-null object
# Student_Count_Total         121 non-null int64
# Student_Count_Low_Income    121 non-null int64
# School_Hours                118 non-null object
# Transportation_El           91 non-null object
# School_Latitude             121 non-null float64
# School_Longitude            121 non-null float64
# Average_ACT_School          117 non-null float64
# Graduation_Rate_School      121 non-null float64
# dtypes: float64(4), int64(4), object(7)
# memory usage: 15.1+ KB

# %%
fb_count = schools.Facebook.count()
tw_count = schools.Twitter.count()
el_count = schools.Transportation_El.count()


print('Rate w/ Facebook Link:', round(fb_count/len(schools), 2))
print('Rate w/ Twitter Link:', round(tw_count/len(schools), 2))
print('Rate w/ El Info:', round(el_count/len(schools), 2))
# Out:
# Rate w/ Facebook Link: 0.54
# Rate w/ Twitter Link: 0.58
# Rate w/ El Info: 0.75

# %% [markdown]
# ### Pickle Raw School Data

# %%
schools.to_pickle('../data/school_data.pkl')
