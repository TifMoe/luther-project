# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from geopy.distance import great_circle
from mpl_toolkits.basemap import Basemap
import matplotlib.cm as cm

% matplotlib inline

print('Pandas version', pd.__version__)
print('Numpy version', np.__version__)
# Out:
# Pandas version 0.20.3
# Numpy version 1.14.0

# %% [markdown]
# ## Read in School Data

# %%
schools = pd.read_pickle('../data/schools_w_social.pkl')

# %%
schools.head()
# Out:
#     School_ID           Short_Name  \
# 10     609764            JUAREZ HS
# 11     400054  NOBLE - PRITZKER HS
# 12     609726            BROOKS HS
# 14     400094              EPIC HS
# 21     609755             YOUNG HS
#
#                                           Long_Name           School_Type  \
# 10      Benito Juarez Community Academy High School          Neighborhood
# 11                    Noble - Pritzker College Prep               Charter
# 12  Gwendolyn Brooks College Preparatory Academy HS  Selective enrollment
# 14                 EPIC Academy Charter High School               Charter
# 21               Whitney M Young Magnet High School  Selective enrollment
#
#       Zip                                        Facebook  \
# 10  60608                                             NaN
# 11  60639        https://www.facebook.com/benoblepritzker
# 12  60628                                             NaN
# 14  60617  https://www.facebook.com/EPICAcademyHighSchool
# 21  60607                  http://www.facebook.com/wmymhs
#
#                                Twitter  Student_Count_Total  \
# 10                                 NaN                 1739
# 11  http://twitter.com/benoblepritzker                  992
# 12   https://twitter.com/BrooksPrepCSL                  959
# 14    https://twitter.com/EPIC_Academy                  523
# 21         http://www.twitter.com/wyhs                 2156
#
#     Student_Count_Low_Income                            School_Hours  \
# 10                      1659                     7:45  AM - 2:35  PM
# 11                       936  M - R 8:05AM. - 3:50PM  F 8:05- 1:30PM
# 12                       692                       8:00 AM - 3:30 PM
# 14                       491                         8:10 AM-3:50 PM
# 21                       891                     8:00  AM - 3:15  PM
#
#    Transportation_El  School_Latitude  School_Longitude  Average_ACT_School  \
# 10   Blue, Pink, Red        41.852667        -87.663732                16.5
# 11       Blue, Brown        41.915214        -87.730127                21.9
# 12            Orange        41.692763        -87.616353                22.5
# 14               NaN        41.744849        -87.550222                17.5
# 21              Blue        41.878603        -87.664233                27.9
#
#     Graduation_Rate_School  fb_likes  tw_followers  tw_tweets
# 10                    80.9       NaN           NaN        NaN
# 11                    90.3    1793.0         275.0      448.0
# 12                    93.4       NaN         408.0     3869.0
# 14                    69.9     424.0         305.0      787.0
# 21                    96.2    4004.0        1708.0      999.0

# %% [markdown]
# ## Convert School Lat/Lons into projected points

# %%
plt.figure(figsize=(6,6))
plt.scatter(schools['School_Longitude'], schools['School_Latitude'], alpha=0.5, c='k')

# %% [markdown]
# # Import Crime Data

# %% [markdown]
# ## Read in crime data

# %%
crimes = pd.read_pickle('../data/cleaned_crimes.pkl')

# %%
crimes.head()
# Out:
#          ID                    Date            Primary Type  Arrest  \
# 0  10801165  01/01/2017 01:00:00 AM                 BATTERY    True
# 1  10801166  01/01/2017 01:23:00 AM  PUBLIC PEACE VIOLATION    True
# 2  10801090  01/01/2017 12:01:00 AM         CRIMINAL DAMAGE   False
# 3  10801213  01/01/2017 01:00:00 AM                 BATTERY   False
# 4  10801214  01/01/2017 01:45:00 AM         CRIMINAL DAMAGE    True
#
#    Community Area  X Coordinate  Y Coordinate   Latitude  Longitude
# 0               8     1175950.0     1908370.0  41.903933 -87.629129
# 1              71     1171453.0     1848804.0  41.740579 -87.647394
# 2              42     1187984.0     1862596.0  41.778047 -87.586388
# 3              30     1158068.0     1888177.0  41.848906 -87.695365
# 4               5     1162249.0     1928318.0  41.958969 -87.678896

# %%
X_crime = crimes.loc[:, 'Longitude']
Y_crime = crimes.loc[:, 'Latitude']

# %%
plt.figure(figsize=(20,20))
plt.scatter(X_crime, Y_crime, alpha=0.01, c='r')
plt.scatter(schools['School_Longitude'], schools['School_Latitude'], alpha=0.7, c='k', s=250)

# %% [markdown]
# ## Find Count of 2017 Crimes in Chicago within a .15 mile radius of the school grounds

# %%
def zip_coordinates(df, lat_col, lon_col, id_col):
    """
    Take a df and column names for the lat/long and id of observations you would like to zip 
    and return a list of tuples with the identifier and lat/long coordinates
    """
    lats = list(df[lat_col])
    lons = list(df[lon_col])
    coords = list(zip(lats, lons))
    
    bound = list(zip(df[id_col], coords))
    
    return bound

# %%
def count_nearby_crimes(school_list, crime_list, radius_max=0.125):
    """
    Take a list of coordinates for schools and list of crimes with coordinates to find the count
    of crimes within some radius of each school. Returns list of crimes the length of the school list
    """
    
    # Count crimes within .125 (~1 city block) of the school 
    nearby_crime_ct = []

    for index, school in enumerate(school_list):

        crime_count = 0

        for index, crime in enumerate(crime_list):
            distance = great_circle(school[1], crime[1]).miles

            if distance < radius_max:
                crime_count += 1

        nearby_crime_ct.append(crime_count)
        
    return nearby_crime_ct

# %%
school_list = zip_coordinates(df=schools, 
                              id_col='School_ID',
                              lat_col='School_Latitude',
                              lon_col='School_Longitude')

crimes_list = zip_coordinates(df=crimes, 
                              id_col='ID',
                              lat_col='Latitude',
                              lon_col='Longitude')

nearby_crimes = count_nearby_crimes(school_list=school_list, crime_list=crimes_list)

# %%
print(len(nearby_crimes))
nearby_crimes[:5]
# Out:
# 121
# [36, 82, 32, 100, 53]

# %%
schools.head()
# Out:
#     School_ID           Short_Name  \
# 10     609764            JUAREZ HS
# 11     400054  NOBLE - PRITZKER HS
# 12     609726            BROOKS HS
# 14     400094              EPIC HS
# 21     609755             YOUNG HS
#
#                                           Long_Name           School_Type  \
# 10      Benito Juarez Community Academy High School          Neighborhood
# 11                    Noble - Pritzker College Prep               Charter
# 12  Gwendolyn Brooks College Preparatory Academy HS  Selective enrollment
# 14                 EPIC Academy Charter High School               Charter
# 21               Whitney M Young Magnet High School  Selective enrollment
#
#       Zip                                        Facebook  \
# 10  60608                                             NaN
# 11  60639        https://www.facebook.com/benoblepritzker
# 12  60628                                             NaN
# 14  60617  https://www.facebook.com/EPICAcademyHighSchool
# 21  60607                  http://www.facebook.com/wmymhs
#
#                                Twitter  Student_Count_Total  \
# 10                                 NaN                 1739
# 11  http://twitter.com/benoblepritzker                  992
# 12   https://twitter.com/BrooksPrepCSL                  959
# 14    https://twitter.com/EPIC_Academy                  523
# 21         http://www.twitter.com/wyhs                 2156
#
#     Student_Count_Low_Income                            School_Hours  \
# 10                      1659                     7:45  AM - 2:35  PM
# 11                       936  M - R 8:05AM. - 3:50PM  F 8:05- 1:30PM
# 12                       692                       8:00 AM - 3:30 PM
# 14                       491                         8:10 AM-3:50 PM
# 21                       891                     8:00  AM - 3:15  PM
#
#    Transportation_El  School_Latitude  School_Longitude  Average_ACT_School  \
# 10   Blue, Pink, Red        41.852667        -87.663732                16.5
# 11       Blue, Brown        41.915214        -87.730127                21.9
# 12            Orange        41.692763        -87.616353                22.5
# 14               NaN        41.744849        -87.550222                17.5
# 21              Blue        41.878603        -87.664233                27.9
#
#     Graduation_Rate_School  fb_likes  tw_followers  tw_tweets
# 10                    80.9       NaN           NaN        NaN
# 11                    90.3    1793.0         275.0      448.0
# 12                    93.4       NaN         408.0     3869.0
# 14                    69.9     424.0         305.0      787.0
# 21                    96.2    4004.0        1708.0      999.0

# %%
schools['crime_counts'] = nearby_crimes

# %%
schools.sort_values('crime_counts', ascending=False)
# Out:
#      School_ID                      Short_Name  \
# 554     400098               NOBLE - MUCHIN HS
# 476     609678                        JONES HS
# 36      400056           NOBLE - ROWE CLARK HS
# 55      400058  NORTH LAWNDALE - CHRISTIANA HS
# 352     610389                          ORR HS
# 29      610518                   AUSTIN CCA HS
# 38      610394                       UPLIFT HS
# 138     400105     URBAN PREP - BRONZEVILLE HS
# 191     609754             CHICAGO MILITARY HS
# 206     609722                       MANLEY HS
# 583     609751                         KING HS
# 113     609704                     FARRAGUT HS
# 651     400097                NOBLE - BULLS HS
# 637     609682                     RICHARDS HS
# 572     610499                      COLLINS HS
# 367     609723                     MARSHALL HS
# 594     400102            URBAN PREP - WEST HS
# 520     400053               NOBLE - GOLDER HS
# 114     400106              NOBLE - JOHNSON HS
# 653     610304             PHOENIX MILITARY HS
# 31      400077            U OF C - WOODLAWN HS
# 200     609748                         YORK HS
# 586     400032               CICS - ELLISON HS
# 603     400091                 CHICAGO TECH HS
# 207     610547             SOUTH SHORE INTL HS
# 285     609759                     CLEMENTE HS
# 401     609725                  MORGAN PARK HS
# 372     609674           CHICAGO VOCATIONAL HS
# 423     609708                      FOREMAN HS
# 14      400094                         EPIC HS
# ..         ...                             ...
# 177     609694                      HANCOCK HS
# 296     609734                         TAFT HS
# 171     609705                       FENGER HS
# 382     609709                    GAGE PARK HS
# 86      609746                      KENWOOD HS
# 122     609724                       MATHER HS
# 358     609737                  VON STEUBEN HS
# 139     400104              INSTITUTO - HEALTH
# 149     610524                       ALCOTT HS
# 598     609695                     AMUNDSEN HS
# 443     610384                     INFINITY HS
# 60      610340              CHICAGO ACADEMY HS
# 10      609764                       JUAREZ HS
# 166     610557           PATHWAYS - ASHBURN HS
# 232     609720                    LANE TECH HS
# 12     Gwendolyn Brooks College Preparatory Academy HS  Selective enrollment
# 585       Jacqueline B Vaughn Occupational High School     Special Education
# 209               Multicultural Academy of Scholarship                 Small
# 288  Acero Charter Schools - Major Hector P. Garcia MD               Charter
# 320                   Eric Solorio Academy High School          Neighborhood
# 475                 World Language Academy High School                 Small
# 203                           Noble - UIC College Prep               Charter
# 517                 Simpson Academy HS for Young Women       Citywide-Option
# 460       George Washington Carver Military Academy HS      Military academy
# 248                                   CICS - Northtown               Charter
# 458      Chicago High School for Agricultural Sciences                Magnet
# 63               Northside Learning Center High School     Special Education
# 272    Greater Lawndale High School For Social Justice                 Small
#
#        Zip                                           Facebook  \
# 554  60602              http://www.facebook.com/BeNobleMuchin
# 476  60605       https://www.facebook.com/JonesCollegePrepHS/
# 36   60651             https://www.facebook.com/BeNobleRCMSA/
# 55   60623                    https://www.facebook.com/nlcphs
# 352  60624      https://www.facebook.com/orracademyhighschool
# 29   60644                                                NaN
# 38   60640                                                NaN
# 138  60616       https://www.facebook.com/UrbanPrepAcademies/
# 191  60653                                                NaN
# 206  60612          https://www.facebook.com/manleyhighschool
# 583  60653         https://www.facebook.com/kingcollegeprephs
# 113  60623     https://www.facebook.com/FarragutCareerAcademy
# 651  60612                                                NaN
# 637  60609                                                NaN
# 572  60623               https://www.facebook.com/AUSLChicago
# 367  60624                                                NaN
# 594  60608       https://www.facebook.com/UrbanPrepAcademies/
# 520  60642         https://www.facebook.com/GolderCollegePrep
# 114  60621                https://www.facebook.com/BeNobleJCP
# 653  60612  https://www.facebook.com/Phoenix-Military-Acad...
# 31   60637           https://www.facebook.com/UCCharterSchool
# 200  60608                                                NaN
# 586  60620                                                NaN
# 603  60608             http://www.facebook.com/ChiTechAcademy
# 207  60649                                                NaN
# 285  60622                http://www.facebook.com/rccachicago
# 401  60643                                                NaN
# 372  60617                                                NaN
# 423  60641                  http://www.facebook.com/foremanhs
# 14   60617     https://www.facebook.com/EPICAcademyHighSchool
# ..     ...                                                ...
# 177  60629                https://www.facebook.com/HancockCPS
# 296  60631                     http://www.facebook.com/tafths
# 171  60628                                                NaN
# 382  60629                https://www.facebook.com/GageParkHS
# 86   60615                                                NaN
# 122  60659                                                NaN
# 358  60625                                                NaN
# 139  60608            https://www.facebook.com/Instituto1977/
# 149  60618         https://www.facebook.com/alcottcollegeprep
# 598  60625                                                NaN
# 443  60623                                                NaN
# 60   60634                                                NaN
# 10   60608                                                NaN
# 166  60652                                                NaN
# 232  60618                 http://www.facebook.com/LaneTechHS
# 370  60634       http://www.facebook.com/SteinmetzCollegePrep
# 454  60625                                                NaN
# 12   60628                                                NaN
# 585  60641                 https://www.facebook.com/Vaughnhs/
# 209  60623                                                NaN
# 288  60632   https://www.facebook.com/UNOCharterSchoolNetwork
# 320  60632             http://www.facebook.com/solorioacademy
# 475  60623                                                NaN
# 203  60608             https://www.facebook.com/BeNobleUICCP/
# 367        -87.708050                15.8                    57.7       NaN
# 594        -87.660107                16.6                    64.1   11744.0
# 520        -87.664483                19.5                    81.7       NaN
# 114        -87.635117                18.2                    77.4    2815.0
# 653        -87.686960                19.0                    91.5     435.0
# 31         -87.598114                17.2                    76.3    1147.0
# 200        -87.695261                 NaN                     1.7       NaN
# 586        -87.668980                16.3                    78.6       NaN
# 603        -87.659095                15.6                    69.5     831.0
# 207        -87.576353                17.9                    71.0       NaN
# 285        -87.686906                15.4                    83.5    2098.0
# 401        -87.665658                17.3                    79.6       NaN
# 372        -87.573268                15.6                    72.6       NaN
# 423        -87.754167                15.3                    65.2     143.0
# 14         -87.550222                17.5                    69.9     424.0
# ..                ...                 ...                     ...       ...
# 177        -87.724470                16.9                    84.6     395.0
# 296        -87.791547                18.9                    85.2    5205.0
# 171        -87.637572                14.7                    49.5       NaN
# 382        -87.688954                14.4                    68.7       NaN
# 86         -87.590421                19.2                    84.6       NaN
# 122        -87.702496                17.4                    72.3       NaN
# 358        -87.713386                21.3                    88.8       NaN
# 139        -87.687240                16.7                    82.8    5899.0
# 149        -87.680562                17.6                    87.1     775.0
# 598        -87.679484                18.2                    82.8       NaN
# 443        -87.735278                18.8                    94.2       NaN
# 60         -87.776847                18.5                    85.4       NaN
# 10         -87.663732                16.5                    80.9       NaN
# 166        -87.704060                15.1                     0.0       NaN
# 232        -87.691013                25.6                    95.9    9209.0
# 370        -87.783515                16.3                    71.3    1468.0
# 454        -87.708708                29.5                    97.8       NaN
# 12         -87.616353                22.5                    93.4       NaN
# 585        -87.764663                 NaN                    27.8     102.0
# 209        -87.735283                14.6                    80.9       NaN
# 288        -87.730467                17.7                    84.5       NaN
# 320        -87.711059                18.4                    80.5    1773.0
# 475        -87.735292                17.5                    77.9       NaN
# 203        -87.676111                22.2                    83.3    1414.0
# 517        -87.668722                16.7                    21.4     152.0
# 460        -87.590620                18.0                    91.0       NaN
# 248        -87.726504                19.4                    83.3     450.0
# 458        -87.717770                20.2                    74.7       NaN
# 63         -87.722386                 NaN                     3.1     335.0
# 272        -87.735299                15.6                    87.5      53.0
#
#      tw_followers  tw_tweets  crime_counts
# 554         287.0      421.0          2145
# 476         455.0      549.0           348
# 36          187.0      205.0           333
# 55            NaN        NaN           229
# 352         213.0       70.0           199
# 29           65.0      184.0           184
# 38           27.0       48.0           175
# 138           NaN        NaN           174
# 191           NaN        NaN           173
# 206           NaN        NaN           154
# 583         308.0      654.0           147
# 113           NaN        NaN           144
# 651           NaN        NaN           144
# 637           NaN        NaN           137
# 572        1939.0     2191.0           128
# 367           NaN        NaN           127
# 594           NaN        NaN           119
# 520           NaN        NaN           117
# 114           NaN        NaN           114
# 653         222.0      164.0           114
# 31          645.0     1174.0           113
# 200           NaN        NaN           112
# 586           NaN        NaN           111
# 603        1541.0     2285.0           109
# 207           NaN        NaN           109
# 285         576.0      397.0           108
# 401         112.0       25.0           103
# 372           NaN        NaN           101
# 423         129.0      262.0           100
# 14          305.0      787.0           100
# ..            ...        ...           ...
# 177         400.0      322.0            50
# 296        2381.0     4468.0            49
# 171           NaN        NaN            49
# 382          28.0       17.0            48
# 86            NaN        NaN            48
# 122         730.0      627.0            47
# 358         698.0     2128.0            42
# 139           NaN        NaN            40
# 149         658.0     1938.0            39
# 598        1344.0     1399.0            38
# 443           NaN        NaN            36
# 60           96.0      342.0            36
# 10            NaN        NaN            36
# 166           NaN        NaN            35
# 232        2823.0     3343.0            35
# 370         573.0     1300.0            34
# 454         292.0       73.0            32
# 12          408.0     3869.0            32
# 585          84.0      366.0            29
# 209           NaN        NaN            24
# 288           NaN        NaN            24
# 320         654.0     1158.0            23
# 475           NaN        NaN            21
# 203           NaN        NaN            18
# 517           NaN        NaN            17
# 460           NaN        NaN            15
# 248           NaN        NaN            13
# 458         502.0      350.0            12
# 63          181.0      160.0             2
# 272           NaN        NaN             1
#
# [121 rows x 19 columns]

# %%
schools.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Deal with Outliers

# %% [markdown]
# ## Find Outliers

# %% [markdown]
# It looks like there are a few schools at the top with a really high count of crime - let's see what this distribution looks like on a density plot

# %%
sns.distplot(schools['crime_counts'])

# %% [markdown]
# Ok, so the top outlier is a school in the loop by Washington and State (high density area with crime likely unrelated to the school - let's find the statistical outliers of schools by crime and checkout out where these schools are located

# %%
schools['crime_counts'].describe()
# Out:
# count     121.000000
# mean       98.214876
# std       195.082897
# min         1.000000
# 25%        50.000000
# 50%        71.000000
# 75%        99.000000
# max      2145.000000
# Name: crime_counts, dtype: float64

# %%
def find_outliers(series, multiplier=1.5):
    """
    Takes as input a series, identifies the outliers as defined as 1.5 * IQR from the .75 Q and return a mask to identify them
    """
    adjusted_IQR = (series.quantile(.75) - series.quantile(.25)) * multiplier
    outlier_lim = series.quantile(.75) + adjusted_IQR
    print(outlier_lim)
    
    outliers = [True if x > outlier_lim else False for x in series]
    
    outlier_count = sum(outliers)
    all_data_count = len(series)
    print('{} outliers identified: {} of all data'.format(outlier_count, round(outlier_count/all_data_count,6)))
    
    return outliers

# %%
crime_outliers = find_outliers(schools['crime_counts'])
schools['crime_outlier'] = crime_outliers
# Out:
# 172.5
# 9 outliers identified: 0.07438 of all data

# %%
X_crime = crimes.loc[:, 'Longitude']
Y_crime = crimes.loc[:, 'Latitude']

# %%
plt.figure(figsize=(20,20))
plt.scatter(X_crime, Y_crime, alpha=0.01, c='lightgrey')
plt.scatter(schools['School_Longitude'], schools['School_Latitude'], alpha=0.7, 
            c=schools['crime_outlier'], edgecolors='k',
            s=schools['crime_counts'])

# %% [markdown]
# ## Replace Outliers w Mean

# %% [markdown]
# Ok, so the two largest dots situated in the loop stick out to me because:
# - They are situated in highly dense areas where crimes unrelated to the school are very likely occuring within 1 city block of the school location
# - These two outliers are not near other, similarly sized dots while the rest of the outliers appear to be relatively consistent with surrounding schools
#
# For now, I'm going to replace these two crime counts with the median count for the dataset

# %%
sorted_schools = schools.sort_values('crime_counts', ascending=False)
sorted_schools.reset_index(inplace=True)

sorted_schools['crime_counts'][0]
# Out:
# 2145

# %%
def replace_top_X_mean(series, indices_to_replace):
    
    others = series
    to_replace = []
    
    for i in indices_to_replace:
        to_replace.append(others.pop(i))
    
    for i, c in enumerate(to_replace):
        to_replace[i] = int(others.mean())
        
    to_replace.extend(others)
        
    return to_replace

# %%
sorted_schools['crime_counts'] = replace_top_X_mean(sorted_schools['crime_counts'], [0,1])

# %%
sorted_schools.head()
# Out:
#    index  School_ID                      Short_Name  \
# 0    100     400098               NOBLE - MUCHIN HS
# 1     91     609678                        JONES HS
# 2      8     400056           NOBLE - ROWE CLARK HS
# 3     10     400058  NORTH LAWNDALE - CHRISTIANA HS
# 4     66     610389                          ORR HS
#
#                                        Long_Name           School_Type    Zip  \
# 0                    Noble - Muchin College Prep               Charter  60602
# 1  William Jones College Preparatory High School  Selective enrollment  60605
# 2    Noble - Rowe-Clark Math and Science Academy               Charter  60651
# 3       North Lawndale College Prep - Christiana               Charter  60623
# 4                        Orr Academy High School          Neighborhood  60624
#
#                                         Facebook  \
# 0          http://www.facebook.com/BeNobleMuchin
# 1   https://www.facebook.com/JonesCollegePrepHS/
# 2         https://www.facebook.com/BeNobleRCMSA/
# 3                https://www.facebook.com/nlcphs
# 4  https://www.facebook.com/orracademyhighschool
#
#                               Twitter  Student_Count_Total  \
# 0   https://twitter.com/BeNobleMuchin                  964
# 1  https://twitter.com/jonescollegehs                 1866
# 2    https://twitter.com/BeNobleRCMSA                  474
# 3                                 NaN                  357
# 4      https://twitter.com/orracademy                  276
#
#    Student_Count_Low_Income      ...        \
# 0                       804      ...
# 1                       732      ...
# 2                       441      ...
# 3                       349      ...
# 4                       263      ...
#
#                                Transportation_El School_Latitude  \
# 0  Blue, Brown, Green, Orange, Pink, Purple, Red       41.882740
# 1                         Blue, Brown, Pink, Red       41.873066
# 2                             Blue, Brown, Green       41.895362
# 3                                          Green       41.858564
# 4                                            NaN       41.894449
#
#    School_Longitude  Average_ACT_School  Graduation_Rate_School  fb_likes  \
# 0        -87.626338                21.8                    86.4     600.0
# 1        -87.627675                26.2                    91.8       NaN
# 2        -87.718047                18.5                    82.4     427.0
# 3        -87.708987                15.3                    67.1    1419.0
# 4        -87.726166                14.2                    39.0     424.0
#
#    tw_followers  tw_tweets  crime_counts  crime_outlier
# 0         287.0      421.0            78           True
# 1         455.0      549.0            78           True
# 2         187.0      205.0           333           True
# 3           NaN        NaN           229           True
# 4         213.0       70.0           199           True
#
# [5 rows x 21 columns]

# %%
plt.figure(figsize=(15,15))
plt.scatter(X_crime, Y_crime, alpha=0.01, c='lightgrey')
plt.scatter(sorted_schools['School_Longitude'], sorted_schools['School_Latitude'], alpha=0.7, 
            c=sorted_schools['crime_counts'], edgecolors='k',
            s=sorted_schools['crime_counts'])

# %% [markdown]
# # Normalize Crime Data

# %% [markdown]
# Because these schools vary in size, I want to normalize the count of crimes taking place around the school by finding the count of crimes per student

# %%
sorted_schools['crimes_per_student'] = [(crimes/students) for (crimes, students) 
                                                        in zip(sorted_schools['crime_counts'], sorted_schools['Student_Count_Total'])]

# I'll also compute crimes per 1000 students for the sake of plotting
sorted_schools['crimes_per_1000_students'] = [crimes * 1000 for crimes in sorted_schools['crimes_per_student']]

# %%
sorted_schools.head()
# Out:
#    index  School_ID                      Short_Name  \
# 0    100     400098               NOBLE - MUCHIN HS
# 1     91     609678                        JONES HS
# 2      8     400056           NOBLE - ROWE CLARK HS
# 3     10     400058  NORTH LAWNDALE - CHRISTIANA HS
# 4     66     610389                          ORR HS
#
#                                        Long_Name           School_Type    Zip  \
# 0                    Noble - Muchin College Prep               Charter  60602
# 1  William Jones College Preparatory High School  Selective enrollment  60605
# 2    Noble - Rowe-Clark Math and Science Academy               Charter  60651
# 3       North Lawndale College Prep - Christiana               Charter  60623
# 4                        Orr Academy High School          Neighborhood  60624
#
#                                         Facebook  \
# 0          http://www.facebook.com/BeNobleMuchin
# 1   https://www.facebook.com/JonesCollegePrepHS/
# 2         https://www.facebook.com/BeNobleRCMSA/
# 3                https://www.facebook.com/nlcphs
# 4  https://www.facebook.com/orracademyhighschool
#
#                               Twitter  Student_Count_Total  \
# 0   https://twitter.com/BeNobleMuchin                  964
# 1  https://twitter.com/jonescollegehs                 1866
# 2    https://twitter.com/BeNobleRCMSA                  474
# 3                                 NaN                  357
# 4      https://twitter.com/orracademy                  276
#
#    Student_Count_Low_Income            ...            School_Longitude  \
# 0                       804            ...                  -87.626338
# 1                       732            ...                  -87.627675
# 2                       441            ...                  -87.718047
# 3                       349            ...                  -87.708987
# 4                       263            ...                  -87.726166
#
#   Average_ACT_School  Graduation_Rate_School  fb_likes  tw_followers  \
# 0               21.8                    86.4     600.0         287.0
# 1               26.2                    91.8       NaN         455.0
# 2               18.5                    82.4     427.0         187.0
# 3               15.3                    67.1    1419.0           NaN
# 4               14.2                    39.0     424.0         213.0
#
#    tw_tweets  crime_counts  crime_outlier  crimes_per_student  \
# 0      421.0            78           True            0.080913
# 1      549.0            78           True            0.041801
# 2      205.0           333           True            0.702532
# 3        NaN           229           True            0.641457
# 4       70.0           199           True            0.721014
#
#    crimes_per_1000_students
# 0                 80.912863
# 1                 41.800643
# 2                702.531646
# 3                641.456583
# 4                721.014493
#
# [5 rows x 23 columns]

# %% [markdown]
# Lets see how this changes our map view

# %%
plt.figure(figsize=(20,20))
plt.scatter(X_crime, Y_crime, alpha=0.01, c='lightgrey')
plt.scatter(sorted_schools['School_Longitude'], sorted_schools['School_Latitude'], alpha=0.9, 
            c=sorted_schools['crimes_per_1000_students'], edgecolors='k',
            s=sorted_schools['crimes_per_1000_students'])

# %% [markdown]
# # Pickle Data

# %%
sorted_schools.to_pickle('../data/schools_crimes.pkl')
